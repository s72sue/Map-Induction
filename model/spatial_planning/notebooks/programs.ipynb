# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
from src.utils import *
from src.map_grid import *
from src.programs import *

# %%
#map_layout = readMap(input('Map file name: '))   # ndarray
map_layout = readMap('stim/four_room.txt')   # ndarray
visualize(map_layout)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks80fc58e7-c665-4a5d-966e-8ab779d8b07b td {border: 1px solid white;}</style><table id="blocks80fc58e7-c665-4a5d-966e-8ab779d8b07b" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [1, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [2, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [3, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [4, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [5, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153,
# ...

# %%
mirror_img = reflect(map_layout, axis=1)
#write_mapcode("stim/mirror_img.txt", mirror_img)
visualize(mirror_img)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks22442549-9438-475c-9999-97dcd22a7b1f td {border: 1px solid white;}</style><table id="blocks22442549-9438-475c-9999-97dcd22a7b1f" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [1, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [2, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [3, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [4, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [5, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153,
# ...

# %%
shortcut = remove_wall(mirror_img, (1,3))
#write_mapcode("stim/shortcut.txt", shortcut)
visualize(shortcut)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks2a0d0347-cfa3-4b4c-bbca-05828f6f8afc td {border: 1px solid white;}</style><table id="blocks2a0d0347-cfa3-4b4c-bbca-05828f6f8afc" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [1, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [2, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [3, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [4, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [5, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153,
# ...

# %%
extension = add_wall(shortcut, (4,3))
#write_mapcode("stim/extension.txt", extension)
visualize(extension)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksf18752a9-2bb4-44ce-932c-7e73fa862492 td {border: 1px solid white;}</style><table id="blocksf18752a9-2bb4-44ce-932c-7e73fa862492" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [1, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [2, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [3, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [4, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [5, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153,
# ...

# %%
original = reflect(extension, axis=1)
#write_mapcode("stim/original.txt", original)
visualize(original)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksd99175b7-a539-41a0-b122-856de6e3c20c td {border: 1px solid white;}</style><table id="blocksd99175b7-a539-41a0-b122-856de6e3c20c" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [1, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [2, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [3, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [4, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [5, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153,
# ...

# %%
rotated = rotate(map_layout, k=1)
#write_mapcode("stim/rotated.txt", rotated)
visualize(rotated)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blockse6f82437-dc19-4d2c-849e-d6c237c8276d td {border: 1px solid white;}</style><table id="blockse6f82437-dc19-4d2c-849e-d6c237c8276d" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [1, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [2, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [3, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [4, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [5, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153,
# ...

# %%
dupx3 = duplicatex(map_layout, k=3)
#write_mapcode("stim/dupx3.txt", dupx3)
visualize(dupx3)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksfb7fa0f5-79b2-4afb-876c-ccb64eb87c21 td {border: 1px solid white;}</style><table id="blocksfb7fa0f5-79b2-4afb-876c-ccb64eb87c21" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [1, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [2, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [3, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [4, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [5, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153,
# ...

# %%
dupy2 = duplicatey(map_layout, k=2)
#write_mapcode("stim/dupy2.txt", dupy2)
visualize(dupy2)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks707772db-04ed-4b86-b770-586b1aac94c3 td {border: 1px solid white;}</style><table id="blocks707772db-04ed-4b86-b770-586b1aac94c3" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [1, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [2, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [3, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [4, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [5, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153,
# ...

# %%
scaledu = scaleu(map_layout, k=2)
#write_mapcode("stim/scaledu.txt", scaledu)
visualize(scaledu)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksb30e15d1-84ef-483c-bc3d-a6961b669a1b td {border: 1px solid white;}</style><table id="blocksb30e15d1-84ef-483c-bc3d-a6961b669a1b" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [1, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [2, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [3, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [4, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [5, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153,
# ...

# %%
scaledx = scalex(map_layout, k=2)
#write_mapcode("stim/scaledx.txt", scaledx)
visualize(scaledx)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blockse6b28f40-f433-474a-b453-cdbb9caf9c59 td {border: 1px solid white;}</style><table id="blockse6b28f40-f433-474a-b453-cdbb9caf9c59" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [1, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [2, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [3, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [4, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [5, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153,
# ...

# %%
scaledy = scaley(map_layout, k=2)
#write_mapcode("stim/scaledy.txt", scaledy)
visualize(scaledy)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks2ece8bfa-0e24-41e6-8d7c-9268883483f5 td {border: 1px solid white;}</style><table id="blocks2ece8bfa-0e24-41e6-8d7c-9268883483f5" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [1, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [2, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [3, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [4, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [5, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153,
# ...

# %%
my_file_data = read_mapcode('stim/four_room.txt')
print(my_file_data)
# Out:
# 8
# 14
# 33333333
# 30003003
# 30003003
# 30333003
# 30000003
# 30003333
# 30003003
# 30003003
# 30000003
# 30003333
# 30003003
# 30003003
# 30000003
# 33333333

# %%
#write_mapcode("stim/mirror_img.txt", mirror_img)

# %%
print(type(my_file_data))
# Out:
# <class 'str'>

# %%
mem_map = readMap('stim/chain_obs/chain_obs3.txt') 
mirror_img = reflect(mem_map, axis=0)
write_mapcode('stim/chain_obs/chainR_obs3.txt', mirror_img)
visualize(mirror_img)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks2d3d843e-8b12-4091-81c6-5f2d267aed8c td {border: 1px solid white;}</style><table id="blocks2d3d843e-8b12-4091-81c6-5f2d267aed8c" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [1, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [2, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [3, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [4, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [5, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153,
# ...

# %%
mem_map = readMap('stim/fourRoomCorr_obs/fourRoomCorr_obs2.txt') 
mirror_img = reflect(mem_map, axis=0)
#write_mapcode("stim/fourRoomCorr_obs/fourRoomCorrR_obs2.txt", mirror_img)
visualize(mirror_img)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks926a8a5e-0354-488b-a6b2-254c933a6a5e td {border: 1px solid white;}</style><table id="blocks926a8a5e-0354-488b-a6b2-254c933a6a5e" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [1, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [2, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [3, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [4, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153, 0, 0);"></td><td title="Index: [5, 0]&#10;Color: (153, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(153,
# ...
